# %% [markdown]
# <a href="https://colab.research.google.com/github/gunggita49-oss/StrukturDataD_Pertemuan1/blob/main/Latihan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list = []

# %%
for i in range(10):
  angka = int(input("Masukkan angka: "))
  list.append(angka)
# Out:
# Masukkan angka: 1
# Masukkan angka: 5
# Masukkan angka: 34
# Masukkan angka: 2
# Masukkan angka: 7
# Masukkan angka: 88
# Masukkan angka: 56
# Masukkan angka: 4
# Masukkan angka: 16
# Masukkan angka: 21

# %%
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [10, 23, 43, 1, 23, 54, 5, 7, 9, 6, 1, 5, 34, 2, 7, 88, 56, 4, 16, 21]
# Nilai maksimum: 88
# Nilai minimum: 1
# Rata-rata: 20.75

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
